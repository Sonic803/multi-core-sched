# %%
import json
#open json file
with open('../multicore_sched/simulations/a.json') as f:
    data = json.load(f)

# %%
key=[i for i in data.keys()][0]

# %%
print(data[key])
# Out:
# {'attributes': {'configname': 'Sim1', 'datetime': '20250119-11:46:05', 'datetimef': '20250119-114605', 'experiment': 'Sim1', 'inifile': 'omnetpp.ini', 'iterationvars': '$0=1, $1=0, $2=false', 'iterationvarsd': '1/0/false', 'iterationvarsf': '1,0,false-', 'measurement': '$0=1, $1=0, $2=false', 'network': 'Computer', 'processid': '554102', 'repetition': '1', 'replication': '#1', 'resultdir': 'results', 'runnumber': '4', 'seedset': '1'}, 'itervars': {}, 'config': [{'extends': 'Default'}, {'**.numCpus': '1'}, {'**.processGenerator.p_bound': '0'}, {'**.scheduler.isFCFS': 'false'}, {'**.processGenerator.IOPercentageCPUbound': '0.2'}, {'**.processGenerator.IOPercentageIObound': '0.8'}, {'**.processGenerator.meanGenerationTime': '0.1s'}, {'**.processGenerator.meanProcessDuration': '1.80s'}, {'network': 'Computer'}, {'sim-time-limit': '100s'}, {'**.vector-recording': 'true'}, {'seed-set': '1'}, {'num-rngs': '3'}, {'repeat': '3'}], 'scalars': [{'module': 'Computer.scheduler', 'name': 'turnarou
# ...
